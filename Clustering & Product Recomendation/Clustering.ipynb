# %%
# %pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\mindy\anaconda3\lib\site-packages (3.0.3)
# Requirement already satisfied: numba>=0.55.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (0.56.4)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (8.10.0)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (3.7.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (1.3.1)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: xxhash in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (3.2.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (0.10.1)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (0.20.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (5.7.0)
# Requirement already satisfied: scipy<2.0.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (1.10.0)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (0.8.3.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (2.6.1)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (4.64.1)
# Requirement already satisfied: requests>=2.27.1 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (0.13.5)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (1.2.1)
# Requirement already satisfied: numpy<1.24,>=1.21 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (1.23.5)
# Requirement already satisfied: pyod>=1.0.8 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: schemdraw==0.15 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: jinja2>=1.2 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (3.3.5)
# Requirement already satisfied: cloudpickle in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\mindy\anaconda3\lib\site-packages (from pycaret) (6.7.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\mindy\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: packaging in c:\users\mindy\anaconda3\lib\site-packages (from deprecation>=2.1.0->pycaret) (22.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mindy\anaconda3\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\mindy\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.11.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\mindy\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.36)
# Requirement already satisfied: decorator in c:\users\mindy\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\mindy\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: colorama in c:\users\mindy\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: stack-data in c:\users\mindy\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\mindy\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\mindy\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.11.2)
# Requirement already satisfied: backcall in c:\users\mindy\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\mindy\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: matplotlib-inline in c:\users\mindy\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\mindy\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\mindy\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\mindy\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.19.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\mindy\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: wheel in c:\users\mindy\anaconda3\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.38.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mindy\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mindy\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mindy\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mindy\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mindy\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mindy\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mindy\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.0.5)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\mindy\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.17.3)
# Requirement already satisfied: fastjsonschema in c:\users\mindy\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jupyter-core in c:\users\mindy\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.2.0)
# Requirement already satisfied: setuptools in c:\users\mindy\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (65.6.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\mindy\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.39.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mindy\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\mindy\anaconda3\lib\site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in c:\users\mindy\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.11.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\mindy\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.9.1)
# Requirement already satisfied: trace-updater>=0.0.8 in c:\users\mindy\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: jupyter-dash>=0.4.2 in c:\users\mindy\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\mindy\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.35)
# Requirement already satisfied: urllib3 in c:\users\mindy\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.14)
# Requirement already satisfied: six in c:\users\mindy\anaconda3\lib\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mindy\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mindy\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mindy\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2022.12.7)
# Requirement already satisfied: scikit-base<0.6.0 in c:\users\mindy\anaconda3\lib\site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1->pycaret) (0.5.0)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\mindy\anaconda3\lib\site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1->pycaret) (1.2.14)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\mindy\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\mindy\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in c:\users\mindy\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.2)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\mindy\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: ansi2html in c:\users\mindy\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (1.8.0)
# Requirement already satisfied: nest-asyncio in c:\users\mindy\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: Werkzeug<2.3.0 in c:\users\mindy\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\mindy\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (4.4.0)
# Requirement already satisfied: retrying in c:\users\mindy\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\mindy\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1->pycaret) (1.14.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\mindy\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\mindy\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\mindy\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\mindy\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.4)
# Requirement already satisfied: debugpy>=1.0 in c:\users\mindy\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\mindy\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\mindy\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mindy\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: wcwidth in c:\users\mindy\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\mindy\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.5.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\mindy\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\mindy\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (2.5.2)
# Requirement already satisfied: executing in c:\users\mindy\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\mindy\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\mindy\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\mindy\anaconda3\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\mindy\anaconda3\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Requirement already satisfied: entrypoints in c:\users\mindy\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\mindy\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\mindy\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\mindy\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.5.4)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\mindy\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.2)
# Requirement already satisfied: prometheus-client in c:\users\mindy\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: argon2-cffi in c:\users\mindy\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\mindy\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\mindy\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: lxml in c:\users\mindy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\mindy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: bleach in c:\users\mindy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\mindy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: tinycss2 in c:\users\mindy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\mindy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\mindy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\mindy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\mindy\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\mindy\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\mindy\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\mindy\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\mindy\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\mindy\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mindy\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\mindy\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mindy\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\mindy\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import colors
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
import pandas as pd

df0 = pd.read_excel("C:\\Asma\\MADT\\Semester 3\\MADT8101\\Customer segmentation\\customer_feature.xlsx")

# %%
df = df0

# %%
df = df.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578091 entries, 0 to 578090
# Data columns (total 25 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ent             578091 non-null  object
#  1   first_date      578091 non-null  datetime64[ns]
#  2   last_date       578091 non-null  datetime64[ns]
#  3   total_qty       578091 non-null  int64
#  4   total_amt       578091 non-null  int64
#  5   no.visit        578091 non-null  int64
#  6   basket_size     578091 non-null  float64
#  7   join_date       578091 non-null  object
#  8   no.join_year    578091 non-null  int64
#  9   visit_period    578091 non-null  int64
#  10  MTBP            578091 non-null  int64
#  11  order_size      578091 non-null  float64
#  12  visit_size      578091 non-null  float64
#  13  no.center       578091 non-null  int64
#  14  ARPU            578091 non-null  float64
#  15  trans_online    578091 non-null  float64
#  16  trans_offline   578091 non-null  float64
#  17  CLTV            578091 non-null  float64
#  18  trans_price_Q1  578091 non-null  float64
#  19  trans_price_Q2  578091 non-null  float64
#  20  trans_price_Q3  578091 non-null  float64
#  21  trans_price_Q4  578091 non-null  float64
#  22  no.end_under    578091 non-null  float64
#  23  total_paid      578091 non-null  int64
#  24  disc_amt        578091 non-null  float64
# dtypes: datetime64[ns](2), float64(13), int64(8), object(2)
# memory usage: 110.3+ MB

# %%
df.describe()
# Out:
#            total_qty     total_amt       no.visit   basket_size  \
# count  578091.000000  5.780910e+05  578091.000000  5.780910e+05
# mean       10.009552  3.475580e+06       3.550078  5.084364e+05
# std       108.749139  6.937046e+06       7.488334  3.543186e+05
# min         1.000000  2.500000e+03       1.000000  2.500000e+03
# 25%         2.000000  1.559000e+06       1.000000  2.925000e+05
# 50%         4.000000  1.690000e+06       2.000000  4.128000e+05
# 75%         8.000000  2.341000e+06       3.000000  5.850000e+05
# max     44546.000000  1.646114e+08     682.000000  4.380000e+06
#
#         no.join_year   visit_period           MTBP    order_size  \
# count  578091.000000  578091.000000  578091.000000  5.780910e+05
# mean       44.746258     102.091468      17.039227  1.173222e+06
# std        58.389070     221.035127      39.398434  6.338836e+05
# min         0.000000       0.000000       0.000000  2.500000e+03
# 25%         1.000000       0.000000       0.000000  6.946000e+05
# 50%         2.000000       1.000000       1.000000  1.119667e+06
# 75%       124.000000      47.000000      14.000000  1.630000e+06
# max       124.000000     916.000000     457.000000  4.654750e+07
#
#           visit_size      no.center  ...   trans_online  trans_offline  \
# count  578091.000000  578091.000000  ...  578091.000000  578091.000000
# mean        2.803533       1.739972  ...       0.465537       0.561436
# std         2.348601       1.728079  ...       0.439013       0.434846
# min         1.000000       1.000000  ...       0.000000       0.000000
# 25%         1.500000       1.000000  ...       0.000000       0.000000
# 50%         2.166667       1.000000  ...       0.500000       0.625000
# 75%         3.600000       2.000000  ...       1.000000       1.000000
# max       420.245283      74.000000  ...       1.000000       1.000000
#
#                CLTV  trans_price_Q1  trans_price_Q2  trans_price_Q3  \
# count  5.780910e+05   578091.000000   578091.000000   578091.000000
# mean   7.083903e+08        0.288643        0.289475        0.253988
# std    5.029009e+08        0.262117        0.297982        0.295598
# min    0.000000e+00        0.000000        0.000000        0.000000
# 25%    3.293578e+08        0.000000        0.000000        0.000000
# 50%    6.371890e+08        0.250000        0.250000        0.166667
# 75%    9.996951e+08        0.500000        0.500000        0.447368
# max    4.161346e+10        1.000000        1.000000        1.000000
#
#        trans_price_Q4   no.end_under    total_paid      disc_amt
# count   578091.000000  578091.000000  5.780910e+05  5.780910e+05
# mean         0.167894       0.789689  1.864826e+05  1.042002e+05
# std          0.282248       4.916385  1.012379e+06  3.560275e+05
# min          0.000000       0.000000  0.000000e+00  0.000000e+00
# 25%          0.000000       0.000000  0.000000e+00  0.000000e+00
# 50%          0.000000       0.000000  0.000000e+00  0.000000e+00
# 75%          0.250000       0.000000  0.000000e+00  2.000000e+04
# max          1.000000    1008.000000  5.010950e+07  1.202250e+07
#
# [8 rows x 21 columns]

# %%
# Drop column
df_features = df.drop(['ent'], axis=1)
df_features = df_features.drop(['first_date'], axis=1)
df_features = df_features.drop(['last_date'], axis=1)
df_features = df_features.drop(['join_date'], axis=1)
df_features = df_features.drop(['total_paid'], axis=1)
#df_features = df_features.drop(['disc_amt'], axis=1)
#df_features = df_features.drop(['no.end_under'], axis=1)
df_features = df_features.drop(['trans_price_Q1'], axis=1)
df_features = df_features.drop(['trans_price_Q2'], axis=1)
df_features = df_features.drop(['trans_price_Q3'], axis=1)
#df_features = df_features.drop(['no.center'], axis=1)
df_features = df_features.drop(['no.join_year'], axis=1)
df_features = df_features.drop(['trans_offline'], axis=1)
df_features = df_features.drop(['trans_online'], axis=1)

# %%
# Standardize the features
scaler = StandardScaler()
df_features_scaled = scaler.fit_transform(df_features)

# %% [markdown]
# ## Find the optimal number of clusters

# %%
# Quick examination of elbow method to find numbers of clusters to make.
print('Elbow Method to determine the number of clusters to be formed:')
Elbow_M = KElbowVisualizer(KMeans(random_state=158), k=10, scoere='calinski_harabasz')
Elbow_M.fit(df_features_scaled)
Elbow_M.show();
# Out:
# Elbow Method to determine the number of clusters to be formed:
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Finding the optimal number of clusters using Elbow Method
#
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
from sklearn import datasets
from sklearn.cluster import KMeans

# Load IRIS dataset
iris = datasets.load_iris()
X = iris.data
y = iris.target

# Instantiate the KMeans models
km = KMeans(n_clusters=3, init='k-means++', max_iter=300, n_init=10, random_state=0)

# Fit the KMeans model
km.fit_predict(X)

# Calculate Silhoutte Score
score = silhouette_score(X, km.labels_, metric='euclidean')

# Print the score
print('Silhouetter Score: %.3f' % score)
# Out:
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Silhouetter Score: 0.553

# %%
from yellowbrick.cluster import SilhouetteVisualizer
 
fig, ax = plt.subplots(2, 2, figsize=(15,8))
for i in [2, 3, 4, 5]:
    '''
    Create KMeans instance for different number of clusters
    '''
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(X)
# Out:
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ## Fit & Predict the model

# %%
# Initiating the K-means Clustering model
KM = KMeans(n_clusters=3, random_state=666)

# %%
# Fit model and predict clusters
yhat_KM = KM.fit_predict(df_features_scaled)
# Out:
# C:\Users\mindy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# create a new column in the scaled dataframe with the cluster labels
df_features_scaled = pd.DataFrame(df_features_scaled, columns=df_features.columns)
df_features_scaled["Clusters"] = pd.Series(yhat_KM, index=df_features_scaled.index)

# %%
# Adding the Clusters feature to the original dataframe.
df["Clusters"] = df_features_scaled["Clusters"]

# %% [markdown]
# ## Principle Component Analysis

# %%
#Initiating PCA to reduce dimentions aka features to 2
pca = PCA(n_components=2)
pca.fit(df_features_scaled)
PCA_ds = pd.DataFrame(pca.transform(df_features_scaled), columns=(["PC1","PC2"]))
PCA_ds.describe().T
# Out:
#         count          mean       std        min       25%       50%  \
# PC1  578091.0 -1.219286e-17  2.030599 -11.043214 -0.883482 -0.465878
# PC2  578091.0 -4.562490e-17  1.840770  -3.636342 -1.453781 -0.019929
#
#           75%         max
# PC1  0.113998  103.988289
# PC2  1.385745  118.303038

# %%
PCA_ds["Clusters"] = yhat_KM

# %%
# Plot the clusters on reduced dimension data
plt.figure(figsize=(10,8))
sns.scatterplot(x="PC1", y="PC2", hue="Clusters", data=PCA_ds, palette="Set2")
plt.show()

# %%
cluster_results = df

# %%
cluster_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578091 entries, 0 to 578090
# Data columns (total 26 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ent             578091 non-null  object
#  1   first_date      578091 non-null  datetime64[ns]
#  2   last_date       578091 non-null  datetime64[ns]
#  3   total_qty       578091 non-null  int64
#  4   total_amt       578091 non-null  int64
#  5   no.visit        578091 non-null  int64
#  6   basket_size     578091 non-null  float64
#  7   join_date       578091 non-null  object
#  8   no.join_year    578091 non-null  int64
#  9   visit_period    578091 non-null  int64
#  10  MTBP            578091 non-null  int64
#  11  order_size      578091 non-null  float64
#  12  visit_size      578091 non-null  float64
#  13  no.center       578091 non-null  int64
#  14  ARPU            578091 non-null  float64
#  15  trans_online    578091 non-null  float64
#  16  trans_offline   578091 non-null  float64
#  17  CLTV            578091 non-null  float64
#  18  trans_price_Q1  578091 non-null  float64
#  19  trans_price_Q2  578091 non-null  float64
#  20  trans_price_Q3  578091 non-null  float64
#  21  trans_price_Q4  578091 non-null  float64
#  22  no.end_under    578091 non-null  float64
#  23  total_paid      578091 non-null  int64
#  24  disc_amt        578091 non-null  float64
#  25  Clusters        578091 non-null  int32
# dtypes: datetime64[ns](2), float64(13), int32(1), int64(8), object(2)
# memory usage: 112.5+ MB

# %%
sku_count = cluster_results.groupby('Clusters')['ent'].nunique()
print(sku_count)
# Out:
# Clusters
# 0     16388
# 1    261875
# 2    299828
# Name: ent, dtype: int64

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578091 entries, 0 to 578090
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   total_qty       578091 non-null  int64
#  1   total_amt       578091 non-null  int64
#  2   no.visit        578091 non-null  int64
#  3   basket_size     578091 non-null  float64
#  4   visit_period    578091 non-null  int64
#  5   MTBP            578091 non-null  int64
#  6   order_size      578091 non-null  float64
#  7   visit_size      578091 non-null  float64
#  8   no.center       578091 non-null  int64
#  9   ARPU            578091 non-null  float64
#  10  CLTV            578091 non-null  float64
#  11  trans_price_Q4  578091 non-null  float64
#  12  no.end_under    578091 non-null  float64
#  13  disc_amt        578091 non-null  float64
# dtypes: float64(8), int64(6)
# memory usage: 61.7 MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc, roc_auc_score
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb
import matplotlib.pyplot as plt

# %%
#Create variable
X = cluster_results.drop(['ent','first_date','last_date','join_date','Clusters','total_paid','trans_price_Q1','trans_offline','trans_price_Q2','no.join_year','trans_online','trans_price_Q3'], axis=1)
y = df['Clusters']

# %%
#train set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40, stratify=y, random_state=42)

# %%
#X variable scaling
scaler = StandardScaler()

x_scaled = scaler.fit_transform(X_train)
X_train_scaled = pd.DataFrame(x_scaled)
X_train_scaled.columns = X_train.columns

x_scaled = scaler.fit_transform(X_test)
X_test_scaled = pd.DataFrame(x_scaled)
X_test_scaled.columns = X_test.columns

# %%
import matplotlib.pyplot as plt

# classification model
def classification_model(clf, X_train, y_train, X_test, y_test, show_feature_importance=True):
    clf_model = clf.fit(X_train, y_train)
    y_hat_train = clf_model.predict(X_train)
    report_train = classification_report(y_train, y_hat_train)

    y_hat_test = clf_model.predict(X_test)
    report_test = classification_report(y_test, y_hat_test)

    print('Training Set Classification Report:')
    print(report_train)
    print('\n')

    print('Test Set Classification Report:')
    print(report_test)
    print('\n')

    if show_feature_importance:
        try:
            print('Standardized Coeff.')
            if hasattr(clf_model, 'coef_'):
                feature_importances = clf_model.coef_[0]
            elif hasattr(clf_model, 'feature_importances_'):
                feature_importances = clf_model.feature_importances_
            else:
                raise AttributeError("Model does not have attribute 'coef_' or 'feature_importances_'")

            coefficients = pd.DataFrame({"Feature": X_train.columns.tolist(), "Importance": feature_importances})
            coefficients = coefficients.sort_values(by="Importance", ascending=False)
            
            # Reverse sort order
            coefficients = coefficients[::-1]

            plt.figure(figsize=(10, 6))
            plt.barh(coefficients["Feature"], coefficients["Importance"])

            # Add data labels
            for i, v in enumerate(coefficients["Importance"]):
                plt.text(v, i, f"{v:.4f}", color='black', va='center')

            plt.xlabel("Importance")
            plt.ylabel("Feature")
            plt.title("Feature Importance")
            plt.show()
        except AttributeError as e:
            print(str(e))

# Random forest
rf_clf = RandomForestClassifier(max_depth=4, random_state=0)
classification_model(rf_clf, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Training Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.89      9833
#            1       0.98      0.97      0.98    157125
#            2       0.97      0.98      0.98    179896
#
#     accuracy                           0.97    346854
#    macro avg       0.97      0.93      0.95    346854
# weighted avg       0.97      0.97      0.97    346854
#
#
#
# Test Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.90      6555
#            1       0.99      0.97      0.98    104750
#            2       0.97      0.99      0.98    119932
#
#     accuracy                           0.98    231237
#    macro avg       0.97      0.94      0.95    231237
# weighted avg       0.98      0.98      0.98    231237
#
#
#
# Standardized Coeff.

# %% [markdown]
# ## Export Train Result

# %%
cluster_results.to_excel('C:\Asma\MADT\Semester 3\MADT8101\Customer segmentation\Customer_ClusterResult.xlsx', index=False)
